# %%
import matplotlib.pyplot as plt
import cv2 
import skimage as ski
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
img = cv2.imread('venom.jpg')

# %%
# plt.imshow(img)

# %%
img.shape
# Out:
# (864, 1536, 3)

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1 = plt.imread('venom.jpg')
plt.imshow(img1)

# %%
img2 = ski.io.imread('venom.jpg')
ski.io.imshow(img1)

# %%
ski.io.imsave('file1.jpg',img)
plt.imsave('file2.jpg',img)
cv2.imwrite('file3.jpg',img)
# Out:
# True

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
ski.io.imshow(img_gray)

# %%
_,img_binary = cv2.threshold(img_gray,50,255,cv2.THRESH_BINARY)
ski.io.imshow(img_binary,)
